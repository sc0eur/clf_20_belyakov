# %% [markdown]
# # Линейная регрессия

# %% [markdown]
# # (ЛИНЕЙНАЯ АГРЕССИЯ)

# %% [markdown]
# Данные содержатся в файле `data/lin_reg.txt`. Прочитать их можно следующим так:

# %%
import numpy as np
D = np.loadtxt('../data/lin_reg.txt', delimiter=',')
X = D[:, :-1]
Y = D[:, -1]

# %% [markdown]
# ## Стандартизируем

# %%
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0) 
Y = (Y - np.mean(Y, axis=0)) / np.std(Y, axis=0)

# %% [markdown]
# При выполнении заданий **нельзя** пользоваться `scikit-learn` и т.п., только `NumPy`/`JAX`/`TF`/`PyTorch` и `matplotlib`/`seaborn`/`plotly`/etc.
#
# 1. Нарисуйте график среднеквадратичной ошибки в зависимости от параметра регуляризации $\alpha$, используя полные данные для обучения и для тестирования.
# 2. Подготовьте исходные данные для 5 fold CV.
# 3. С помощью CV найдите оптимальное значение $\alpha$ на какой-нибудь сетке значений.
# 4. Постройте валидационную кривую.
# 5. Постройте кривую обучения.

# %%
import torch.nn
import torch
from torch.optim import SGD

# %%
inputs = torch.from_numpy(X)
outputs = torch.from_numpy(np.expand_dims(Y, axis=1))

# %%
train_ds = torch.utils.data.TensorDataset(inputs, outputs)

# %%
batch_size = 16
train_dl = torch.utils.data.DataLoader(train_ds, batch_size)

# %%
losses = []
for a in np.linspace(0,0.003,100):
    print("alpha: ", a)
    model = torch.nn.Linear(4,1)
    model = model.double()
    mse = torch.nn.functional.mse_loss
    optim = SGD(model.parameters(), lr=0.001)
    num_epochs = 1000
    for epoch in range(num_epochs):
        if epoch%100==0:
            print("epoch: ", epoch)
        for xb,yb in train_dl:
            pred = model(xb)
            l2_reg = torch.tensor(0.)
            for param in model.parameters():
                l2_reg += param.norm(2)
            loss = mse(pred, yb) + a * l2_reg

            loss.backward()
            optim.step()
            optim.zero_grad()
    losses.append(mse(model(inputs.double()), outputs.double()).item())
# Out:
# alpha:  0.0
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  3.0303030303030302e-05
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  6.0606060606060605e-05
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  9.09090909090909e-05
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.00012121212121212121
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.00015151515151515152
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0001818181818181818
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.00021212121212121213
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.00024242424242424242
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.00027272727272727274
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.00030303030303030303
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0003333333333333333
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0003636363636363636
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0003939393939393939
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.00042424242424242425
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.00045454545454545455
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.00048484848484848484
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0005151515151515151
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0005454545454545455
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0005757575757575757
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0006060606060606061
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0006363636363636363
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0006666666666666666
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.000696969696969697
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0007272727272727272
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0007575757575757576
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0007878787878787878
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0008181818181818182
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0008484848484848485
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0008787878787878787
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0009090909090909091
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0009393939393939393
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0009696969696969697
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.001
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0010303030303030303
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0010606060606060605
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.001090909090909091
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0011212121212121212
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0011515151515151514
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0011818181818181819
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0012121212121212121
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0012424242424242424
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0012727272727272726
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.001303030303030303
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0013333333333333333
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0013636363636363635
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.001393939393939394
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0014242424242424242
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0014545454545454545
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.001484848484848485
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0015151515151515152
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0015454545454545454
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0015757575757575756
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.001606060606060606
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0016363636363636363
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0016666666666666666
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.001696969696969697
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0017272727272727272
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0017575757575757575
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.001787878787878788
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0018181818181818182
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0018484848484848484
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0018787878787878787
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0019090909090909091
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0019393939393939393
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.00196969696969697
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0020303030303030303
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0020606060606060605
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0020909090909090908
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002121212121212121
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0021515151515151517
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002181818181818182
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002212121212121212
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0022424242424242424
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0022727272727272726
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002303030303030303
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002333333333333333
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0023636363636363638
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002393939393939394
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0024242424242424242
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0024545454545454545
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0024848484848484847
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002515151515151515
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002545454545454545
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002575757575757576
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002606060606060606
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0026363636363636363
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0026666666666666666
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002696969696969697
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002727272727272727
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0027575757575757577
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002787878787878788
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002818181818181818
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0028484848484848484
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.0028787878787878787
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002909090909090909
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.002939393939393939
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.00296969696969697
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# alpha:  0.003
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900

# %% [markdown]
# # На большой сетке не понятно

# %%
import matplotlib.pyplot as plt

plt.plot(np.linspace(0,0.5,100), losses)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(np.linspace(0,0.2,51), losses)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(np.linspace(0,0.02,21), losses)
plt.grid()
plt.show()

# %% [markdown]
# # На маленькой понятно

# %%
import matplotlib.pyplot as plt

plt.plot(np.linspace(0,0.003,100), losses)
plt.grid()
plt.show()

# %%
np.linspace(0,0.003,100)[losses.index(min(losses))]
# Out:
# 0.0023636363636363638

# %%
idxs = [0, 200, 400, 600, 800, 1000]
kfold_losses = []
train_losses = []
valid_losses = []
for i in range(len(idxs)-1):
    print(idxs[i])
    test_X = inputs[idxs[i]:idxs[i+1]]
    test_Y = outputs[idxs[i]:idxs[i+1]]
    if i==0:
        train_X = inputs[idxs[i+1]:]
        train_Y = outputs[idxs[i+1]:]
    else:
        train_X = torch.cat((inputs[:idxs[i]], inputs[idxs[i+1]:]), dim=0)
        train_Y = torch.cat((outputs[:idxs[i]], outputs[idxs[i+1]:]), dim=0)
    lss = []
    train_ds = torch.utils.data.TensorDataset(train_X, train_Y)   
    batch_size = 20
    train_dl = torch.utils.data.DataLoader(train_ds, batch_size)
    for a in np.linspace(0,0.003,51):
        model = torch.nn.Linear(4,1)
        model = model.double()
        mse = torch.nn.functional.mse_loss
        optim = SGD(model.parameters(), lr=0.001)
        num_epochs = 100
        t_loss = []
        v_loss = []
        for epoch in range(num_epochs):
            for xb,yb in train_dl:
                pred = model(xb)
                l2_reg = torch.tensor(0.)
                for param in model.parameters():
                    l2_reg += param.norm(2)
#                 print(l2_reg, a, mse(pred, yb))
                loss = mse(pred, yb) + a * l2_reg

                loss.backward()
                optim.step()
                optim.zero_grad()
                if (epoch+ 1) % 10 == 0:
                    train_loss = mse(train_Y.double(), model(train_X.double())).item()
                    val_loss = mse(test_Y.double(), model(test_X.double())).item()

                    t_loss.append(train_loss)
                    v_loss.append(val_loss)
                    
        train_losses.append(t_loss)
        valid_losses.append(v_loss)
        
        lss.append(mse(model(test_X.double()), test_Y.double()).item())
        
    kfold_losses.append(lss)
# Out:
# 0
# 200
# 400
# 600
# 800

# %% [markdown]
# # Средние значения ошибки для сетки параметра

# %%
plt.plot(np.linspace(0,0.003,51),np.array(kfold_losses).mean(axis=0))
plt.grid()
plt.show()

# %%
mean_losses = np.array(kfold_losses).mean(axis=0)
np.linspace(0,0.003,51)[np.argmin(mean_losses)]
# Out:
# 0.00108

# %%
ticks = np.arange(400)

plt.plot(ticks, np.array(valid_losses).mean(axis=0), label='val')
plt.plot(ticks, np.array(train_losses).mean(axis=0), label='train')

plt.legend()
